# %% [markdown]
# <a href="https://colab.research.google.com/github/looffee16-axe/ML/blob/main/ML_P1W1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = {
    "size_sqft": [600, 800, 1000, 1200, 1500, 1800, 2000, 2200],
    "bedrooms": [1, 2, 2, 3, 3, 4, 4, 5],
    "price": [120000, 150000, 180000, 220000, 260000, 300000, 340000, 380000],
    "age_of_house": [20, 15, 10, 8, 5, 3, 2, 1]
}

df = pd.DataFrame(data)

df
# Out:
#    size_sqft  bedrooms   price  age_of_house
# 0        600         1  120000            20
# 1        800         2  150000            15
# 2       1000         2  180000            10
# 3       1200         3  220000             8
# 4       1500         3  260000             5
# 5       1800         4  300000             3
# 6       2000         4  340000             2
# 7       2200         5  380000             1

# %%
X = df[["size_sqft", "bedrooms", "age_of_house"]]
y = df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
print("Training data:")
print(X_train)

print("\nTesting data:")
print(X_test)
# Out:
# Training data:
#    size_sqft  bedrooms  age_of_house
# 7       2200         5             1
# 2       1000         2            10
# 4       1500         3             5
# 3       1200         3             8
# 6       2000         4             2
#
# Testing data:
#    size_sqft  bedrooms  age_of_house
# 1        800         2            15
# 5       1800         4             3
# 0        600         1            20

# %%
print("Training data:")
print(y_train)

print("\nTesting data:")
print(y_test)
# Out:
# Training data:
# 7    380000
# 2    180000
# 4    260000
# 3    220000
# 6    340000
# Name: price, dtype: int64
#
# Testing data:
# 1    150000
# 5    300000
# 0    120000
# Name: price, dtype: int64
